# %%
import pandas as pd
import numpy as py
import collections
from collections import Counter
from itertools import groupby
from operator import itemgetter

# %%
HP=pd.read_csv('Harry Potter Data.csv')
HP=HP.dropna(subset=['Location'])
HPT=HP.T.to_dict().values()
for item in HPT:
    item['times']=len(item['Page'].split(','))

towhom=[]

# %%
HP.head()
# Out:
#                                   Book  Chapter    Page      Location  \
# 0  Harry Potter & the Sorcerer's Stone      1.0    6, 7  Privet Drive
# 1  Harry Potter & the Sorcerer's Stone      1.0    6, 7  Privet Drive
# 2  Harry Potter & the Sorcerer's Stone      1.0       9  Privet Drive
# 3  Harry Potter & the Sorcerer's Stone      1.0   9, 15  Privet Drive
# 4  Harry Potter & the Sorcerer's Stone      1.0  14, 15  Privet Drive
#
#        Character - Name               To Whom  Male=1 Female=0  Creature=1  \
# 0           Mr. Dursley          Mrs. Dursley     1.0      NaN         0.0
# 1          Mrs. Dursley           Mr. Dursley     0.0        .         0.0
# 2      Albus Dumbledore  Professor McGonagall     1.0      NaN         0.0
# 3  Professor McGonagall      Albus Dumbledore     0.0        .         0.0
# 4         Rubeus Hagrid      Albus Dumbledore     1.0      NaN         0.0
#
#    Theme     ...      Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  \
# ...

# %%
def request(name):
    for item in HPT:
       
        if item['Character - Name']==name:
            tuple1 = (item['To Whom'], item['times'])
            print tuple1
            towhom.append(tuple1)
    return towhom

# %%
request('Hermoine Granger')
# Out:
# ('Harry Potter', 2)
# ('Ron Weasley', 3)
# ('Harry Potter', 1)
# ('Percy Weasley', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 1)
# ('Harry Potter', 2)
# ('Ron Weasley', 1)
# ('Harry Potter', 2)
# ('Harry Potter', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 1)
# ('Professor McGonagall', 2)
# ('Harry Potter', 1)
# ('Harry Potter', 1)
# ('Harry Potter', 1)
# ('Rubeus Hagrid', 2)
# ('Ron Weasley', 1)
# ('Rubeus Hagrid', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 3)
# ('Neville', 1)
# ('Ron Weasley', 1)
# ('Harry Potter', 1)
# ('Ron Weasley', 3)
# ('Harry Potter', 1)
# [('Petunia Dursley', 2),
#  ('Vernon Dursely', 2),
#  ('Snake', 1),
#  ('Dudley Dursley', 1),
#  ('Petunia Dursley', 2),
#  ('Vernon Dursely', 4),
#  ('Rubeus Hagrid', 10),
#  ('Vernon Dursely', 2),
#  ('Petunia Dursley', 1),
#  ('Rubeus Hagrid', 3),
#  ('Rubeus Hagrid', 2),
# ...

# %%
d=collections.defaultdict(int)
a=[]
b=[]
for na,ti in towhom:
    if not na in a:a.append(na)
    d[na]+=ti
for f in a:
    tuple2=(f,d[f])
    print tuple2
    b.append(tuple2)
network=[]    
def newtuple(query):
    for i in range(len(b)):
        tuple3=(query,b[i][0],b[i][1])
        network.append(tuple3)
        
    return network
# Out:
# ('Petunia Dursley', 5)
# ('Vernon Dursely', 10)
# ('Snake', 1)
# ('Dudley Dursley', 1)
# ('Rubeus Hagrid', 32)
# ('Dedalus Diggle', 1)
# ('Professor Quirrell', 1)
# ('Griphook (goblin)', 1)
# ('pale boy', 2)
# ('Mr. Ollivander', 3)
# ('Mother Weasley', 1)
# ('George Weasley', 3)
# ('Fred Weasley', 3)
# ('Ron Weasley', 52)
# ('Neville', 7)
# ('Hermoine Granger', 18)
# ('Draco Malfoy', 5)
# ('Percy Weasley', 4)
# ('Sir Nicholas de Mimsy-Porpington (ghost)', 1)
# ('Snape', 4)
# ('Peeves - a poltergeist', 1)
# ('Portrait of the Fat Lady on the 7th floor', 2)
# ('Professor Flitwick', 1)
# ('Oliver Wood', 4)
# ('Seamus Finnigan', 1)
# ('Madam Pince', 1)
# ('Parents', 1)
# ('Albus Dumbledore', 3)
# ('Harry Potter', 23)
# ('Professor McGonagall', 2)

# %%
newtuple('Hermoine Granger')
# Out:
# [('Hermoine Granger', 'Petunia Dursley', 5),
#  ('Hermoine Granger', 'Vernon Dursely', 10),
#  ('Hermoine Granger', 'Snake', 1),
#  ('Hermoine Granger', 'Dudley Dursley', 1),
#  ('Hermoine Granger', 'Rubeus Hagrid', 32),
#  ('Hermoine Granger', 'Dedalus Diggle', 1),
#  ('Hermoine Granger', 'Professor Quirrell', 1),
#  ('Hermoine Granger', 'Griphook (goblin)', 1),
#  ('Hermoine Granger', 'pale boy', 2),
#  ('Hermoine Granger', 'Mr. Ollivander', 3),
#  ('Hermoine Granger', 'Mother Weasley', 1),
#  ('Hermoine Granger', 'George Weasley', 3),
#  ('Hermoine Granger', 'Fred Weasley', 3),
#  ('Hermoine Granger', 'Ron Weasley', 52),
#  ('Hermoine Granger', 'Neville', 7),
#  ('Hermoine Granger', 'Hermoine Granger', 18),
#  ('Hermoine Granger', 'Draco Malfoy', 5),
#  ('Hermoine Granger', 'Percy Weasley', 4),
#  ('Hermoine Granger', 'Sir Nicholas de Mimsy-Porpington (ghost)', 1),
#  ('Hermoine Granger', 'Snape', 4),
#  ('Hermoine Granger', 'Peeves - a poltergeist', 1),
# ...

# %%
import networkx as nx
G = nx.DiGraph()
G.add_weighted_edges_from(network)
import matplotlib.pyplot as plt
elarge=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] >10]
esmall=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] <=10]
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,node_size=700)
nx.draw_networkx_edges(G,pos,edgelist=elarge,
                    width=6)
nx.draw_networkx_edges(G,pos,edgelist=esmall,
                    width=6,alpha=0.5,edge_color='b',style='dashed')
nx.draw_networkx_labels(G,pos,font_size=10,font_family='sans-serif')
plt.axis('off')
plt.savefig("weighted_graph.png") # save as png
plt.show()

# %%
import networkx as nx
G = nx.DiGraph()
G.add_weighted_edges_from(network)
import matplotlib.pyplot as plt
elarge=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] >10]
esmall=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] <=10]
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,node_size=100)
nx.draw_networkx_edges(G,pos,edgelist=elarge,
                    width=4)
nx.draw_networkx_edges(G,pos,edgelist=esmall,
                    width=4,alpha=0.5,edge_color='b',style='dashed')
nx.draw_networkx_labels(G,pos,font_size=12,font_family='sans-serif')
plt.axis('off')
plt.savefig("weighted_graph.png") # save as png
plt.show()

# %%
import networkx as nx
G = nx.DiGraph()
G.add_weighted_edges_from(network)
import matplotlib.pyplot as plt
elarge=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] >10]
esmall=[(u,v) for (u,v,d) in G.edges(data=True) if d['weight'] <=10]
pos=nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,node_size=100)
nx.draw_networkx_edges(G,pos,edgelist=elarge,
                    width=4)
nx.draw_networkx_edges(G,pos,edgelist=esmall,
                    width=4,alpha=0.5,edge_color='b',style='dashed')
nx.draw_networkx_labels(G,pos,font_size=12,font_family='sans-serif')
plt.axis('off')
plt.savefig("weighted_graph.png") # save as png
plt.show()
